# %% [markdown]
# # LSTM

# %%
# utility
import numpy as np 
import pandas as pd 
import string
import re

# visualization
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix

# model 
from tensorflow.python.keras.preprocessing.text import Tokenizer
from tensorflow.python.keras.preprocessing.sequence import pad_sequences
from keras.models import Sequential
from keras.layers import Dense, Embedding, LSTM, Bidirectional
import keras
from keras.utils.np_utils import to_categorical

#nltk and sklearn
from sklearn.preprocessing import LabelEncoder
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords

# File path
import os
import os.path
from os import path

# Translator
import googletrans
from googletrans import Translator

# calc accuracy
from sklearn.metrics import accuracy_score 
from sklearn.metrics import classification_report

# %%
# original hindi file
filename  = 'Eng-Hin-data/english-anot-shuff'
orig_df = pd.read_csv(filename + '.csv',  
               delimiter=',')
orig_df.columns = ['Text', 'Label']

# %%
# Displaying eg tweet before translation
orig_df.Text[2]
# Out:
# "'Thorpe becomes England head coach for Pakistan T20 series with Silverwood rested"

# %%
data = orig_df

# %%
sentiment =  data['Label'].values

# %%
data.groupby('Label').describe()
# Out:
#        Text
#       count unique                                                top freq
# Label
# 0      3555   3555  'Semi finals of under 9â€™s #cricket on Sunday...    1
# 1      2398   2398  '@MMArslanrajp00t @hend_mana u must learn hist...    1
# 2      2484   2484  '#AirIndia RADICAL ISLAMIC TERRORISMS IN KEREL...    1

# %%
sns.countplot(data.Label)
plt.xlabel('Tweets')
plt.title('Number of Tweets')
# Out:
# Text(0.5, 1.0, 'Number of Tweets')

# %%
print(len(data))
# Out:
# 8438

# %%
def clean_text(text):
    text = text.lower()
    
    pattern = re.compile('http[s]?://(?:[a-zA-Z]|[0-9]|[$-_@.&+]|[!*\(\),]|(?:%[0-9a-fA-F][0-9a-fA-F]))+')
    text = pattern.sub('', text)
    text = " ".join(filter(lambda x:x[0]!='@', text.split()))
    text = text.lower()
    text = re.sub(r"i'm", "i am", text)
    text = re.sub(r"he's", "he is", text)
    text = re.sub(r"she's", "she is", text)
    text = re.sub(r"that's", "that is", text)        
    text = re.sub(r"what's", "what is", text)
    text = re.sub(r"where's", "where is", text) 
    text = re.sub(r"\'ll", " will", text)  
    text = re.sub(r"\'ve", " have", text)  
    text = re.sub(r"\'re", " are", text)
    text = re.sub(r"\'d", " would", text)
    text = re.sub(r"\'ve", " have", text)
    text = re.sub(r"won't", "will not", text)
    text = re.sub(r"don't", "do not", text)
    text = re.sub(r"did't", "did not", text)
    text = re.sub(r"can't", "can not", text)
    text = re.sub(r"it's", "it is", text)
    text = re.sub(r"couldn't", "could not", text)
    text = re.sub(r"have't", "have not", text)
    text = re.sub(r"[,.\"\'!@#$%^&*(){}?/;`~:<>+=-]", "", text)
    return text

# %%
def CleanTokenize(df):
    tweets = list()
    lines = data["Text"].values.tolist()
    
    for line in lines:
        if isinstance(line, str):
            line = clean_text(line)
        else:
            continue
        # tokenize the text
        tokens = word_tokenize(line)
        # remove puntuations
        table = str.maketrans('', '', string.punctuation)
        stripped = [w.translate(table) for w in tokens]
        # remove non alphabetic characters
        words = [word for word in stripped if word.isalpha()]
        stop_words = set(stopwords.words("english"))
        # remove stop words
        words = [w for w in words if not w in stop_words]
        tweets.append(words)
    return tweets

def Tokenize(df):
    tweets = list()
    lines = data["Text"].values.tolist()
    
    for line in lines:
        if isinstance(line, str):
            # tokenize the text
            tokens = word_tokenize(line)
        else:
            continue

        tweets.append(tokens)
    return tweets

tweets = CleanTokenize(data)
#tweets = Tokenize(data)

# %%
from collections import Counter
from wordcloud import WordCloud, ImageColorGenerator
pos_data = data.loc[data['Label'] == 1]
pos_head_lines = CleanTokenize(pos_data)
pos_lines = [j for sub in pos_head_lines for j in sub] 
word_could_dict=Counter(pos_lines)

wordcloud = WordCloud(width = 1000, height = 500).generate_from_frequencies(word_could_dict)
plt.figure(figsize=(15,8))
plt.imshow(wordcloud)
plt.axis("off")
# Out:
# (-0.5, 999.5, 499.5, -0.5)

# %%
validation_split = 0.2
max_length = 25


tokenizer_obj = Tokenizer()
tokenizer_obj.fit_on_texts(tweets)
sequences = tokenizer_obj.texts_to_sequences(tweets)

word_index = tokenizer_obj.word_index
print("unique tokens - ",len(word_index))
vocab_size = len(tokenizer_obj.word_index) + 1
print('vocab size -', vocab_size)

lines_pad = pad_sequences(sequences, maxlen=max_length, padding='post')
sentiment =  data['Label'].values

indices = np.arange(lines_pad.shape[0])
np.random.shuffle(indices)
lines_pad = lines_pad[indices]
sentiment = sentiment[indices]

le = LabelEncoder()
sentiment = le.fit_transform(sentiment)
# transfor from a array to a vector
sentiment = sentiment.reshape(-1,1)


num_validation_samples = int(validation_split * lines_pad.shape[0])

X_train_pad = lines_pad[:-num_validation_samples]
y_train = sentiment[:-num_validation_samples]

X_test_pad = lines_pad[-num_validation_samples:]
y_test = sentiment[-num_validation_samples:]

y_train = to_categorical(y_train)
y_test = to_categorical(y_test)
# Out:
# unique tokens -  14306
# vocab size - 14307

# %%
print('Shape of X_train_pad:', X_train_pad.shape)
print('Shape of y_train:', y_train.shape)

print('Shape of X_test_pad:', X_test_pad.shape)
print('Shape of y_test:', y_test.shape)
# Out:
# Shape of X_train_pad: (6750, 25)
# Shape of y_train: (6750, 3)
# Shape of X_test_pad: (1687, 25)
# Shape of y_test: (1687, 3)

# %%
embeddings_index = {}

# Glove Stanford NLP 
f = open('glove.6B.300d.txt', encoding = "utf-8")
for line in f:
    values = line.split()
    word = values[0]
    coefs = np.asarray(values[1:], dtype='float32')
    embeddings_index[word] = coefs
f.close()

print('Found %s word vectors.' % len(embeddings_index))
# Out:
# Found 400000 word vectors.

# %%
embedding_dim = 300

embedding_matrix = np.zeros((len(word_index) + 1, embedding_dim))
c = 0
for word, i in word_index.items():
    embedding_vector = embeddings_index.get(word)
    if embedding_vector is not None:
        c+=1
        embedding_matrix[i] = embedding_vector

# %%
embedding_layer = Embedding(len(word_index) + 1,
                            embedding_dim,
                            weights=[embedding_matrix],
                            input_length=max_length,
                            trainable=False)

# %% [markdown]
# ## LSTM Model

# %%
def createModel(embedding_layer):
    model = Sequential()
    model.add(embedding_layer)
    model.add(LSTM(256, dropout=0.2, recurrent_dropout=0.50))
    model.add(Dense(3, activation='softmax'))

    model.compile(loss='categorical_crossentropy', optimizer = keras.optimizers.RMSprop(learning_rate=1e-3), metrics=['acc'])
    return model

model = createModel(embedding_layer)
model.summary()
# Out:
# Model: "sequential_13"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_1 (Embedding)      (None, 25, 300)           4292100
# _________________________________________________________________
# lstm_13 (LSTM)               (None, 256)               570368
# _________________________________________________________________
# dense_13 (Dense)             (None, 3)                 771
# =================================================================
# Total params: 4,863,239
# Trainable params: 571,139
# Non-trainable params: 4,292,100
# _________________________________________________________________

# %%
history = model.fit(X_train_pad, y_train, batch_size=32, epochs=6, validation_data=(X_test_pad, y_test), verbose=2)
# Out:
# Epoch 1/6
# 211/211 - 20s - loss: 0.7421 - acc: 0.7367 - val_loss: 0.6864 - val_acc: 0.7653
# Epoch 2/6
# 211/211 - 19s - loss: 0.6887 - acc: 0.7696 - val_loss: 0.6850 - val_acc: 0.7653
# Epoch 3/6
# 211/211 - 19s - loss: 0.6768 - acc: 0.7750 - val_loss: 0.6897 - val_acc: 0.7647
# Epoch 4/6
# 211/211 - 19s - loss: 0.6595 - acc: 0.7833 - val_loss: 0.6850 - val_acc: 0.7647
# Epoch 5/6
# 211/211 - 19s - loss: 0.6521 - acc: 0.7868 - val_loss: 0.6818 - val_acc: 0.7688
# Epoch 6/6
# 211/211 - 19s - loss: 0.6383 - acc: 0.7919 - val_loss: 0.6982 - val_acc: 0.7564

# %%
results = model.evaluate(X_test_pad, y_test, batch_size=32)
# Out:
# 53/53 [==============================] - 1s 20ms/step - loss: 0.6982 - acc: 0.7564

# %%
# Plot results
acc = history.history['acc']
val_acc = history.history['val_acc']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(1, len(acc)+1)

plt.plot(epochs, acc, 'g', label='Training accuracy')
plt.plot(epochs, val_acc, 'r', label='Validation accuracy')
plt.title('Training and validation accuracy')
plt.legend()

plt.figure()

plt.plot(epochs, loss, 'g', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()

plt.show()

# %%
import random
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score 
from sklearn.model_selection import KFold
# KFold cross-validation
kFold = 10
scores = []
validation_split = 0.1
max_length = 25
results = []
train_res =[]
print("LSTM with Glove.6B.300d: ")
for i in range(kFold):
    print("Fold: ", i+1)
    prediction_val = []
    Y_test = []
    scores=[]
    random_shuff = random.randint(1, 7000)
    X_train_pad, X_test_pad, y_train, y_test = train_test_split(lines_pad, to_categorical(sentiment), test_size=0.10, shuffle = True, random_state=random_shuff)
    model = createModel(embedding_layer)
    history = model.fit(X_train_pad, y_train, batch_size=32, epochs=6, validation_data=(X_test_pad, y_test), verbose=1)
    
    print("Results for current fold:")
    print("Evaluation on training data")
    train_res.append(model.evaluate(X_train_pad, y_train, batch_size=128))
    
    print("Evaluation on testing data")
    results.append(model.evaluate(X_test_pad, y_test, batch_size=128))
    
    y_pred = model.predict(X_test_pad)
    for p in y_pred:
        prediction_val.append(np.argmax(p))
    for t in y_test:
        Y_test.append(np.argmax(t))
    scoreValue = accuracy_score(Y_test,prediction_val)
    scores.append(scoreValue)
# Out:
# LSTM with Glove.6B.300d:
# Fold:  1
# Epoch 1/6
# 238/238 [==============================] - 22s 92ms/step - loss: 0.7329 - acc: 0.7450 - val_loss: 0.7581 - val_acc: 0.7334
# Epoch 2/6
# 238/238 [==============================] - 21s 90ms/step - loss: 0.6847 - acc: 0.7701 - val_loss: 0.7549 - val_acc: 0.7429
# Epoch 3/6
# 238/238 [==============================] - 21s 90ms/step - loss: 0.6699 - acc: 0.7766 - val_loss: 0.7923 - val_acc: 0.7334
# Epoch 4/6
# 238/238 [==============================] - 21s 90ms/step - loss: 0.6544 - acc: 0.7876 - val_loss: 0.7531 - val_acc: 0.7287
# Epoch 5/6
# 238/238 [==============================] - 21s 90ms/step - loss: 0.6491 - acc: 0.7874 - val_loss: 0.7514 - val_acc: 0.7370
# Epoch 6/6
# 238/238 [==============================] - 21s 90ms/step - loss: 0.6389 - acc: 0.7919 - val_loss: 0.7553 - val_acc: 0.7382
# Results for current fold:
# Evaluation on training data
# 60/60 [==============================] - 3s 53ms/step - loss: 0.6204 - acc: 0.8064
# Evaluation on testing data
# 7/7 [==============================] - 0s 43ms/step - loss: 0.7553 - acc: 0.7382
# Fold:  2
# Epoch 1/6
# 238/238 [==============================] - 23s 95ms/step - loss: 0.7401 - acc: 0.7346 - val_loss: 0.7355 - val_acc: 0.7417
# Epoch 2/6
# 238/238 [==============================] - 21s 90ms/step - loss: 0.6886 - acc: 0.7685 - val_loss: 0.7645 - val_acc: 0.7405
# Epoch 3/6
# 238/238 [==============================] - 21s 90ms/step - loss: 0.6721 - acc: 0.7740 - val_loss: 0.7257 - val_acc: 0.7429
# Epoch 4/6
# 238/238 [==============================] - 21s 89ms/step - loss: 0.6567 - acc: 0.7834 - val_loss: 0.7284 - val_acc: 0.7488
# Epoch 5/6
# 238/238 [==============================] - 21s 89ms/step - loss: 0.6453 - acc: 0.7872 - val_loss: 0.7354 - val_acc: 0.7441
# Epoch 6/6
# 238/238 [==============================] - 21s 89ms/step - loss: 0.6378 - acc: 0.7927 - val_loss: 0.7269 - val_acc: 0.7441
# Results for current fold:
# Evaluation on training data
# 60/60 [==============================] - 3s 54ms/step - loss: 0.6060 - acc: 0.8061
# Evaluation on testing data
# 7/7 [==============================] - 0s 46ms/step - loss: 0.7269 - acc: 0.7441
# Fold:  3
# Epoch 1/6
# 238/238 [==============================] - 22s 92ms/step - loss: 0.7323 - acc: 0.7431 - val_loss: 0.8544 - val_acc: 0.6872
# Epoch 2/6
# 238/238 [==============================] - 21s 90ms/step - loss: 0.6897 - acc: 0.7656 - val_loss: 0.7160 - val_acc: 0.7429
# Epoch 3/6
# 238/238 [==============================] - 21s 90ms/step - loss: 0.6761 - acc: 0.7749 - val_loss: 0.7478 - val_acc: 0.7429
# Epoch 4/6
# 238/238 [==============================] - 21s 89ms/step - loss: 0.6598 - acc: 0.7827 - val_loss: 0.7014 - val_acc: 0.7630
# Epoch 5/6
# 238/238 [==============================] - 21s 90ms/step - loss: 0.6505 - acc: 0.7864 - val_loss: 0.7353 - val_acc: 0.7512
# Epoch 6/6
# 238/238 [==============================] - 21s 89ms/step - loss: 0.6408 - acc: 0.7920 - val_loss: 0.7440 - val_acc: 0.7559
# Results for current fold:
# Evaluation on training data
# 60/60 [==============================] - 3s 54ms/step - loss: 0.6177 - acc: 0.8059
# Evaluation on testing data
# 7/7 [==============================] - 0s 46ms/step - loss: 0.7440 - acc: 0.7559
# Fold:  4
# Epoch 1/6
# 238/238 [==============================] - 22s 92ms/step - loss: 0.7424 - acc: 0.7342 - val_loss: 0.7157 - val_acc: 0.7464
# Epoch 2/6
# 238/238 [==============================] - 21s 89ms/step - loss: 0.6904 - acc: 0.7669 - val_loss: 0.7201 - val_acc: 0.7417
# Epoch 3/6
# 238/238 [==============================] - 21s 89ms/step - loss: 0.6677 - acc: 0.7776 - val_loss: 0.7508 - val_acc: 0.7536
# Epoch 4/6
# 238/238 [==============================] - 21s 89ms/step - loss: 0.6595 - acc: 0.7799 - val_loss: 0.7442 - val_acc: 0.7536
# Epoch 5/6
# 238/238 [==============================] - 21s 89ms/step - loss: 0.6555 - acc: 0.7851 - val_loss: 0.7037 - val_acc: 0.7618
# Epoch 6/6
# 238/238 [==============================] - 21s 89ms/step - loss: 0.6398 - acc: 0.7922 - val_loss: 0.7097 - val_acc: 0.7595
# Results for current fold:
# Evaluation on training data
# 60/60 [==============================] - 3s 55ms/step - loss: 0.6165 - acc: 0.8055
# Evaluation on testing data
# 7/7 [==============================] - 0s 45ms/step - loss: 0.7097 - acc: 0.7595
# Fold:  5
# Epoch 1/6
# 238/238 [==============================] - 22s 92ms/step - loss: 0.7420 - acc: 0.7362 - val_loss: 0.7385 - val_acc: 0.7263
# Epoch 2/6
# 238/238 [==============================] - 22s 91ms/step - loss: 0.6905 - acc: 0.7679 - val_loss: 0.7414 - val_acc: 0.7346
# Epoch 3/6
# 238/238 [==============================] - 21s 90ms/step - loss: 0.6736 - acc: 0.7745 - val_loss: 0.7088 - val_acc: 0.7476
# Epoch 4/6
# 238/238 [==============================] - 21s 90ms/step - loss: 0.6605 - acc: 0.7795 - val_loss: 0.7413 - val_acc: 0.7500
# Epoch 5/6
# 238/238 [==============================] - 21s 90ms/step - loss: 0.6506 - acc: 0.7890 - val_loss: 0.7383 - val_acc: 0.7500
# Epoch 6/6
# 238/238 [==============================] - 21s 90ms/step - loss: 0.6412 - acc: 0.7931 - val_loss: 0.7224 - val_acc: 0.7441
# Results for current fold:
# Evaluation on training data
# 60/60 [==============================] - 3s 54ms/step - loss: 0.6096 - acc: 0.8077
# Evaluation on testing data
# 7/7 [==============================] - 0s 44ms/step - loss: 0.7224 - acc: 0.7441
# Fold:  6
# Epoch 1/6
# 238/238 [==============================] - 22s 92ms/step - loss: 0.7481 - acc: 0.7354 - val_loss: 0.7007 - val_acc: 0.7654
# Epoch 2/6
# 238/238 [==============================] - 21s 90ms/step - loss: 0.6960 - acc: 0.7639 - val_loss: 0.6714 - val_acc: 0.7690
# Epoch 3/6
# 238/238 [==============================] - 21s 90ms/step - loss: 0.6783 - acc: 0.7724 - val_loss: 0.6708 - val_acc: 0.7701
# Epoch 4/6
# 238/238 [==============================] - 21s 89ms/step - loss: 0.6660 - acc: 0.7809 - val_loss: 0.6879 - val_acc: 0.7701
# Epoch 5/6
# 238/238 [==============================] - 21s 89ms/step - loss: 0.6542 - acc: 0.7851 - val_loss: 0.6658 - val_acc: 0.7749
# Epoch 6/6
# 238/238 [==============================] - 21s 89ms/step - loss: 0.6434 - acc: 0.7913 - val_loss: 0.6791 - val_acc: 0.7773
# Results for current fold:
# Evaluation on training data
# 60/60 [==============================] - 3s 54ms/step - loss: 0.6123 - acc: 0.8068
# Evaluation on testing data
# 7/7 [==============================] - 0s 44ms/step - loss: 0.6791 - acc: 0.7773
# Fold:  7
# Epoch 1/6
# 238/238 [==============================] - 22s 92ms/step - loss: 0.7479 - acc: 0.7333 - val_loss: 0.6946 - val_acc: 0.7678
# Epoch 2/6
# 238/238 [==============================] - 21s 89ms/step - loss: 0.6917 - acc: 0.7662 - val_loss: 0.7150 - val_acc: 0.7666
# Epoch 3/6
# 238/238 [==============================] - 21s 89ms/step - loss: 0.6742 - acc: 0.7748 - val_loss: 0.6883 - val_acc: 0.7796
# Epoch 4/6
# 238/238 [==============================] - 21s 89ms/step - loss: 0.6620 - acc: 0.7789 - val_loss: 0.6945 - val_acc: 0.7761
# Epoch 5/6
# 238/238 [==============================] - 21s 90ms/step - loss: 0.6503 - acc: 0.7868 - val_loss: 0.6961 - val_acc: 0.7690
# Epoch 6/6
# 238/238 [==============================] - 21s 89ms/step - loss: 0.6431 - acc: 0.7917 - val_loss: 0.6886 - val_acc: 0.7749
# Results for current fold:
# Evaluation on training data
# 60/60 [==============================] - 3s 55ms/step - loss: 0.6147 - acc: 0.8050
# Evaluation on testing data
# 7/7 [==============================] - 0s 44ms/step - loss: 0.6886 - acc: 0.7749
# Fold:  8
# Epoch 1/6
# 238/238 [==============================] - 22s 92ms/step - loss: 0.7483 - acc: 0.7352 - val_loss: 0.6696 - val_acc: 0.7808
# Epoch 2/6
# 238/238 [==============================] - 21s 90ms/step - loss: 0.6944 - acc: 0.7649 - val_loss: 0.6448 - val_acc: 0.7844
# Epoch 3/6
# 238/238 [==============================] - 21s 90ms/step - loss: 0.6811 - acc: 0.7724 - val_loss: 0.6853 - val_acc: 0.7618
# Epoch 4/6
# 238/238 [==============================] - 21s 89ms/step - loss: 0.6698 - acc: 0.7774 - val_loss: 0.6423 - val_acc: 0.7844
# Epoch 5/6
# 238/238 [==============================] - 21s 89ms/step - loss: 0.6581 - acc: 0.7815 - val_loss: 0.6443 - val_acc: 0.7891
# Epoch 6/6
# 238/238 [==============================] - 21s 89ms/step - loss: 0.6479 - acc: 0.7882 - val_loss: 0.6360 - val_acc: 0.7891
# Results for current fold:
# Evaluation on training data
# 60/60 [==============================] - 3s 55ms/step - loss: 0.6176 - acc: 0.8036
# Evaluation on testing data
# 7/7 [==============================] - 0s 45ms/step - loss: 0.6360 - acc: 0.7891
# Fold:  9
# Epoch 1/6
# 238/238 [==============================] - 22s 92ms/step - loss: 0.7437 - acc: 0.7365 - val_loss: 0.7000 - val_acc: 0.7559
# Epoch 2/6
# 238/238 [==============================] - 21s 90ms/step - loss: 0.6919 - acc: 0.7658 - val_loss: 0.7409 - val_acc: 0.7393
# Epoch 3/6
# 238/238 [==============================] - 21s 90ms/step - loss: 0.6740 - acc: 0.7748 - val_loss: 0.6962 - val_acc: 0.7690
# Epoch 4/6
# 238/238 [==============================] - 21s 90ms/step - loss: 0.6628 - acc: 0.7794 - val_loss: 0.6924 - val_acc: 0.7701
# Epoch 5/6
# 238/238 [==============================] - 21s 89ms/step - loss: 0.6548 - acc: 0.7861 - val_loss: 0.6713 - val_acc: 0.7701
# Epoch 6/6
# 238/238 [==============================] - 21s 89ms/step - loss: 0.6441 - acc: 0.7909 - val_loss: 0.6795 - val_acc: 0.7796
# Results for current fold:
# Evaluation on training data
# 60/60 [==============================] - 3s 54ms/step - loss: 0.6324 - acc: 0.8051
# Evaluation on testing data
# 7/7 [==============================] - 0s 46ms/step - loss: 0.6795 - acc: 0.7796
# Fold:  10
# Epoch 1/6
# 238/238 [==============================] - 22s 91ms/step - loss: 0.7408 - acc: 0.7348 - val_loss: 0.6822 - val_acc: 0.7690
# Epoch 2/6
# 238/238 [==============================] - 21s 89ms/step - loss: 0.6932 - acc: 0.7652 - val_loss: 0.6760 - val_acc: 0.7678
# Epoch 3/6
# 238/238 [==============================] - 21s 89ms/step - loss: 0.6778 - acc: 0.7726 - val_loss: 0.6673 - val_acc: 0.7701
# Epoch 4/6
# 238/238 [==============================] - 21s 89ms/step - loss: 0.6658 - acc: 0.7811 - val_loss: 0.6636 - val_acc: 0.7773
# Epoch 5/6
# 238/238 [==============================] - 21s 89ms/step - loss: 0.6521 - acc: 0.7855 - val_loss: 0.6655 - val_acc: 0.7820
# Epoch 6/6
# 238/238 [==============================] - 21s 89ms/step - loss: 0.6444 - acc: 0.7905 - val_loss: 0.6788 - val_acc: 0.7808
# Results for current fold:
# Evaluation on training data
# 60/60 [==============================] - 3s 54ms/step - loss: 0.6210 - acc: 0.8063
# Evaluation on testing data
# 7/7 [==============================] - 0s 45ms/step - loss: 0.6788 - acc: 0.7808

# %%
import statistics 

# mean_scores = statistics.mean(scores)
# print("predicted value", mean_scores)
score = []
for i in results:
    score.append(i[1])
x = statistics.mean(score)
    
print("Kfold Mean: ", x)
# Out:
# Kfold Mean:  0.764336496591568

# %%
results2 = confusion_matrix(Y_test,prediction_val)
print ('Confusion Matrix :')
print(results2) 
print ('Accuracy Score :',accuracy_score(Y_test,prediction_val))
print ('Report : ')
print (classification_report(Y_test,prediction_val))
# Out:
# Confusion Matrix :
# [[312  32  44]
#  [ 22 186  23]
#  [ 37  27 161]]
# Accuracy Score : 0.7808056872037915
# Report :
#               precision    recall  f1-score   support
#
#            0       0.84      0.80      0.82       388
#            1       0.76      0.81      0.78       231
#            2       0.71      0.72      0.71       225
#
#     accuracy                           0.78       844
#    macro avg       0.77      0.77      0.77       844
# weighted avg       0.78      0.78      0.78       844
