# %% [markdown]
# # LSTM

# %%
# utility
import numpy as np 
import pandas as pd 
import string
import re

# visualization
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix

# model 
from tensorflow.python.keras.preprocessing.text import Tokenizer
from tensorflow.python.keras.preprocessing.sequence import pad_sequences
from keras.models import Sequential
from keras.layers import Dense, Embedding, LSTM, Bidirectional
import keras
from keras.utils.np_utils import to_categorical

#nltk and sklearn
from sklearn.preprocessing import LabelEncoder
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords

# File path
import os
import os.path
from os import path

# Translator
# import googletrans
# from googletrans import Translator

# calc accuracy
from sklearn.metrics import accuracy_score 
from sklearn.metrics import classification_report

# %% [markdown]
# ### Data

# %%
# original english file
filename  = 'Eng-Hin-data/english-anot-shuffled'
orig_df = pd.read_csv(filename + '.csv',  
               delimiter=',')
orig_df.columns = ['Text', 'Label']

# %%
orig_df["Text"] = orig_df["Text"].astype(str)
orig_df["Label"] = orig_df["Label"].astype(str)
data = orig_df

# %%
# Displaying eg tweet
orig_df.Text[6]
# Out:
# "'@SakibulHoque8 @ImranKhanPTI Terrorist is a Muslim.ðŸ˜€"

# %%
sentiment =  data['Label'].values

# %%
data.groupby('Label').describe()
# Out:
#        Text
#       count unique                                                top freq
# Label
# 0      3555   3555  '@BBCSport Dreamt up by the same people that t...    1
# 1      2398   2398  'Happy Islamic New Year-âœ¨" 1 Muharram 1442 H...    1
# 2      2485   2485  'fuck you mohammed bin zayed and fuck you trum...    1

# %%
sns.countplot(data.Label)
plt.xlabel('Tweets')
plt.title('Number of Tweets')
# Out:
# Text(0.5, 1.0, 'Number of Tweets')

# %% [markdown]
# ### Data Preprocessing

# %%
def clean_text(text):
    text = text.lower()
    
    pattern = re.compile('http[s]?://(?:[a-zA-Z]|[0-9]|[$-_@.&+]|[!*\(\),]|(?:%[0-9a-fA-F][0-9a-fA-F]))+')
    text = pattern.sub('', text)
    text = " ".join(filter(lambda x:x[0]!='@', text.split()))
    text = text.lower()
    text = re.sub(r"i'm", "i am", text)
    text = re.sub(r"he's", "he is", text)
    text = re.sub(r"she's", "she is", text)
    text = re.sub(r"that's", "that is", text)        
    text = re.sub(r"what's", "what is", text)
    text = re.sub(r"where's", "where is", text) 
    text = re.sub(r"\'ll", " will", text)  
    text = re.sub(r"\'ve", " have", text)  
    text = re.sub(r"\'re", " are", text)
    text = re.sub(r"\'d", " would", text)
    text = re.sub(r"\'ve", " have", text)
    text = re.sub(r"won't", "will not", text)
    text = re.sub(r"don't", "do not", text)
    text = re.sub(r"did't", "did not", text)
    text = re.sub(r"can't", "can not", text)
    text = re.sub(r"it's", "it is", text)
    text = re.sub(r"couldn't", "could not", text)
    text = re.sub(r"have't", "have not", text)
    text = re.sub(r"[,.\"\'!@#$%^&*(){}?/;`~:<>+=-]", "", text)
    return text

# %%
def CleanTokenize(df):
    tweets = list()
    lines = data["Text"].values.tolist()
    
    for line in lines:
        if isinstance(line, str):
            line = clean_text(line)
        else:
            continue
        # tokenize the text
        tokens = word_tokenize(line)
        # remove puntuations
        table = str.maketrans('', '', string.punctuation)
        stripped = [w.translate(table) for w in tokens]
        # remove non alphabetic characters
        words = [word for word in stripped if word.isalpha()]
        stop_words = set(stopwords.words("english"))
        # remove stop words
        words = [w for w in words if not w in stop_words]
        tweets.append(words)
    return tweets

def Tokenize(df):
    tweets = list()
    lines = data["Text"].values.tolist()
    
    for line in lines:
        if isinstance(line, str):
            # tokenize the text
            tokens = word_tokenize(line)
        else:
            continue

        tweets.append(tokens)
    return tweets

#tweets = CleanTokenize(data)
tweets = Tokenize(data)

# %%
from collections import Counter
from wordcloud import WordCloud, ImageColorGenerator
pos_data = data.loc[data['Label'] == 1]
pos_head_lines = CleanTokenize(pos_data)
pos_lines = [j for sub in pos_head_lines for j in sub] 
word_could_dict=Counter(pos_lines)

wordcloud = WordCloud(width = 1000, height = 500).generate_from_frequencies(word_could_dict)
plt.figure(figsize=(15,8))
plt.imshow(wordcloud)
plt.axis("off")
# Out:
# (-0.5, 999.5, 499.5, -0.5)

# %% [markdown]
# ### Splitting data

# %%
validation_split = 0.1
max_length = 128


tokenizer_obj = Tokenizer()
tokenizer_obj.fit_on_texts(tweets)
sequences = tokenizer_obj.texts_to_sequences(tweets)

word_index = tokenizer_obj.word_index
print("unique tokens - ",len(word_index))
vocab_size = len(tokenizer_obj.word_index) + 1
print('vocab size -', vocab_size)

lines_pad = pad_sequences(sequences, maxlen=max_length, padding='post')
sentiment =  data['Label'].values

indices = np.arange(lines_pad.shape[0])
np.random.shuffle(indices)
lines_pad = lines_pad[indices]
sentiment = sentiment[indices]

le = LabelEncoder()
sentiment = le.fit_transform(sentiment)
# transfor from a array to a vector
sentiment = sentiment.reshape(-1,1)


num_validation_samples = int(validation_split * lines_pad.shape[0])

X_train_pad = lines_pad[:-num_validation_samples]
y_train = sentiment[:-num_validation_samples]

X_test_pad = lines_pad[-num_validation_samples:]
y_test = sentiment[-num_validation_samples:]

y_train = to_categorical(y_train)
y_test = to_categorical(y_test)
# Out:
# unique tokens -  20142
# vocab size - 20143

# %%
print('Shape of X_train_pad:', X_train_pad.shape)
print('Shape of y_train:', y_train.shape)

print('Shape of X_test_pad:', X_test_pad.shape)
print('Shape of y_test:', y_test.shape)
# Out:
# Shape of X_train_pad: (7595, 128)
# Shape of y_train: (7595, 3)
# Shape of X_test_pad: (843, 128)
# Shape of y_test: (843, 3)

# %% [markdown]
# ### Glove from paper DSWI

# %%
embeddings_index = {}

# Glove from paper DSWI
f = open('Online_supplement_1 word vectors.csv', encoding='latin1')
count = 0
for line in f:
    if count == 0:
        count = 1
        line = 0
    else:
        values = line.split()
        word = values[0]
        coefs = np.asarray(values[1:], dtype='float32')
        embeddings_index[word] = coefs
f.close()

print('Found %s word vectors.' % len(embeddings_index))
# Out:
# Found 1181930 word vectors.

# %%
embedding_dim = 50

embedding_matrix = np.zeros((len(word_index) + 1, embedding_dim))
c = 0
for word, i in word_index.items():
    embedding_vector = embeddings_index.get(word)
    if embedding_vector is not None:
        c+=1
        embedding_matrix[i] = embedding_vector

# %%
embedding_layer = Embedding(len(word_index) + 1,
                            embedding_dim,
                            weights=[embedding_matrix],
                            input_length=max_length,
                            trainable=False)

# %% [markdown]
# ## LSTM Model

# %%
def createModel(embedding_layer):
    model = Sequential()
    model.add(embedding_layer)
    model.add(LSTM(512, dropout=0.2, recurrent_dropout=0.50))
    model.add(Dense(3, activation='softmax'))

    model.compile(loss='categorical_crossentropy', optimizer = keras.optimizers.RMSprop(learning_rate=1e-3), metrics=['acc'])
    return model

model = createModel(embedding_layer)
model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_3 (Embedding)      (None, 128, 50)           1007150
# _________________________________________________________________
# lstm_4 (LSTM)                (None, 512)               1153024
# _________________________________________________________________
# dense_4 (Dense)              (None, 3)                 1539
# =================================================================
# Total params: 2,161,713
# Trainable params: 1,154,563
# Non-trainable params: 1,007,150
# _________________________________________________________________

# %%
history = model.fit(X_train_pad, y_train, batch_size=32, epochs=3, validation_data=(X_test_pad, y_test), verbose=2)
# Out:
# Epoch 1/3
# 238/238 - 189s - loss: 1.0849 - acc: 0.4200 - val_loss: 1.0979 - val_acc: 0.4199
# Epoch 2/3
# 238/238 - 208s - loss: 1.0838 - acc: 0.4215 - val_loss: 1.0828 - val_acc: 0.4199
# Epoch 3/3
# 238/238 - 210s - loss: 1.0835 - acc: 0.4215 - val_loss: 1.0800 - val_acc: 0.4199

# %%
results = model.evaluate(X_test_pad, y_test, batch_size=32)
# Out:
# 27/27 [==============================] - 5s 182ms/step - loss: 1.0800 - acc: 0.4199

# %%
# Plot results
acc = history.history['acc']
val_acc = history.history['val_acc']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(1, len(acc)+1)

plt.plot(epochs, acc, 'g', label='Training accuracy')
plt.plot(epochs, val_acc, 'r', label='Validation accuracy')
plt.title('Training and validation accuracy')
plt.legend()

plt.figure()

plt.plot(epochs, loss, 'g', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()

plt.show()

# %% [markdown]
# ### 10 Fold cross validation

# %%
import random
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score 
from sklearn.model_selection import KFold
# KFold cross-validation
kFold = 10
scores = []
validation_split = 0.1
max_length = 25
results = []
train_res = []
print("LSTM with Glove from DSWI: ")
for i in range(kFold):
    print("Fold: ", i+1)
    prediction_val = []
    Y_test = []
    scores=[]
    random_shuff = random.randint(1, 7000)
    X_train_pad, X_test_pad, y_train, y_test = train_test_split(lines_pad, to_categorical(sentiment), test_size=0.10, shuffle = True, random_state=random_shuff)
    model = createModel(embedding_layer)
    history = model.fit(X_train_pad, y_train, batch_size=32, epochs=6, validation_data=(X_test_pad, y_test), verbose=1)
    
    print("Results for current fold:")
    print("Evaluating on train data")
    train_res.append(model.evaluate(X_train_pad, y_train, batch_size=128))
    print("Evaluating on test data")
    results.append(model.evaluate(X_test_pad, y_test, batch_size=128))
    
    y_pred = model.predict(X_test_pad)
    for p in y_pred:
        prediction_val.append(np.argmax(p))
    for t in y_test:
        Y_test.append(np.argmax(t))
    scoreValue = accuracy_score(Y_test,prediction_val)
    scores.append(scoreValue)
# Out:
# LSTM with Glove from DSWI:
# Fold:  1
# Epoch 1/6
# 238/238 [==============================] - 212s 889ms/step - loss: 1.1069 - acc: 0.4191 - val_loss: 1.0811 - val_acc: 0.4230
# Epoch 2/6
# 238/238 [==============================] - 210s 884ms/step - loss: 1.0952 - acc: 0.4194 - val_loss: 1.0797 - val_acc: 0.4230
# Epoch 3/6
# 238/238 [==============================] - 210s 882ms/step - loss: 1.0862 - acc: 0.4209 - val_loss: 1.1066 - val_acc: 0.4230
# Epoch 4/6
# 238/238 [==============================] - 210s 882ms/step - loss: 1.0992 - acc: 0.4173 - val_loss: 1.0816 - val_acc: 0.4230
# Epoch 5/6
# 238/238 [==============================] - 208s 875ms/step - loss: 1.1157 - acc: 0.3983 - val_loss: 1.0928 - val_acc: 0.3152
# Epoch 6/6
# 238/238 [==============================] - 208s 873ms/step - loss: 1.0891 - acc: 0.4083 - val_loss: 1.0857 - val_acc: 0.4230
# Results for current fold:
# Evaluating on train data
# 60/60 [==============================] - 36s 592ms/step - loss: 1.0906 - acc: 0.4211
# Evaluating on test data
# 7/7 [==============================] - 3s 491ms/step - loss: 1.0857 - acc: 0.4230
# Fold:  2
# Epoch 1/6
# 238/238 [==============================] - 209s 879ms/step - loss: 1.1263 - acc: 0.4170 - val_loss: 1.0754 - val_acc: 0.4372
# Epoch 2/6
# 238/238 [==============================] - 209s 878ms/step - loss: 1.0911 - acc: 0.4188 - val_loss: 1.0768 - val_acc: 0.4372
# Epoch 3/6
# 238/238 [==============================] - 208s 875ms/step - loss: 1.0876 - acc: 0.4194 - val_loss: 1.0780 - val_acc: 0.4372
# Epoch 4/6
# 238/238 [==============================] - 192s 809ms/step - loss: 1.0847 - acc: 0.4186 - val_loss: 1.0796 - val_acc: 0.4372
# Epoch 5/6
# 238/238 [==============================] - 187s 787ms/step - loss: 1.0851 - acc: 0.4193 - val_loss: 1.0772 - val_acc: 0.4372
# Epoch 6/6
# 238/238 [==============================] - 187s 785ms/step - loss: 1.0850 - acc: 0.4181 - val_loss: 1.0759 - val_acc: 0.4372
# Results for current fold:
# Evaluating on train data
# 60/60 [==============================] - 32s 538ms/step - loss: 1.0826 - acc: 0.4195
# Evaluating on test data
# 7/7 [==============================] - 3s 447ms/step - loss: 1.0759 - acc: 0.4372
# Fold:  3
# Epoch 1/6
# 238/238 [==============================] - 188s 788ms/step - loss: 1.1095 - acc: 0.4176 - val_loss: 1.0737 - val_acc: 0.4550
# Epoch 2/6
# 238/238 [==============================] - 188s 789ms/step - loss: 1.1027 - acc: 0.4170 - val_loss: 1.0748 - val_acc: 0.4550
# Epoch 3/6
# 238/238 [==============================] - 187s 785ms/step - loss: 1.0867 - acc: 0.4166 - val_loss: 1.0732 - val_acc: 0.4550
# Epoch 4/6
# 238/238 [==============================] - 187s 786ms/step - loss: 1.0907 - acc: 0.4169 - val_loss: 1.0691 - val_acc: 0.4550
# Epoch 5/6
# 238/238 [==============================] - 187s 787ms/step - loss: 1.0856 - acc: 0.4168 - val_loss: 1.0688 - val_acc: 0.4550
# Epoch 6/6
# 238/238 [==============================] - 187s 784ms/step - loss: 1.0860 - acc: 0.4166 - val_loss: 1.0701 - val_acc: 0.4550
# Results for current fold:
# Evaluating on train data
# 60/60 [==============================] - 33s 547ms/step - loss: 1.0831 - acc: 0.4176
# Evaluating on test data
# 7/7 [==============================] - 3s 440ms/step - loss: 1.0701 - acc: 0.4550
# Fold:  4
# Epoch 1/6
# 238/238 [==============================] - 188s 788ms/step - loss: 1.0950 - acc: 0.4127 - val_loss: 1.0859 - val_acc: 0.4242
# Epoch 2/6
# 238/238 [==============================] - 187s 787ms/step - loss: 1.0867 - acc: 0.4203 - val_loss: 1.0824 - val_acc: 0.4242
# Epoch 3/6
# 238/238 [==============================] - 187s 785ms/step - loss: 1.1205 - acc: 0.4082 - val_loss: 1.0950 - val_acc: 0.4242
# Epoch 4/6
# 238/238 [==============================] - 188s 790ms/step - loss: 1.1271 - acc: 0.3798 - val_loss: 1.0875 - val_acc: 0.4242
# Epoch 5/6
# 238/238 [==============================] - 187s 784ms/step - loss: 1.0966 - acc: 0.4026 - val_loss: 1.0840 - val_acc: 0.4242
# Epoch 6/6
# 238/238 [==============================] - 187s 785ms/step - loss: 1.0937 - acc: 0.4052 - val_loss: 1.0995 - val_acc: 0.4242
# Results for current fold:
# Evaluating on train data
# 60/60 [==============================] - 33s 547ms/step - loss: 1.0972 - acc: 0.4210
# Evaluating on test data
# 7/7 [==============================] - 3s 456ms/step - loss: 1.0995 - acc: 0.4242
# Fold:  5
# Epoch 1/6
# 238/238 [==============================] - 189s 796ms/step - loss: 1.1144 - acc: 0.4173 - val_loss: 1.0790 - val_acc: 0.4336
# Epoch 2/6
# 238/238 [==============================] - 189s 793ms/step - loss: 1.0994 - acc: 0.4199 - val_loss: 1.0778 - val_acc: 0.4336
# Epoch 3/6
# 238/238 [==============================] - 189s 795ms/step - loss: 1.0847 - acc: 0.4199 - val_loss: 1.0771 - val_acc: 0.4336
# Epoch 4/6
# 238/238 [==============================] - 190s 798ms/step - loss: 1.0857 - acc: 0.4201 - val_loss: 1.0780 - val_acc: 0.4336
# Epoch 5/6
# 238/238 [==============================] - 187s 786ms/step - loss: 1.0896 - acc: 0.4166 - val_loss: 1.0824 - val_acc: 0.4336
# Epoch 6/6
# 238/238 [==============================] - 189s 793ms/step - loss: 1.0844 - acc: 0.4190 - val_loss: 1.0784 - val_acc: 0.4336
# Results for current fold:
# Evaluating on train data
# 60/60 [==============================] - 33s 551ms/step - loss: 1.0825 - acc: 0.4199
# Evaluating on test data
# 7/7 [==============================] - 3s 460ms/step - loss: 1.0784 - acc: 0.4336
# Fold:  6
# Epoch 1/6
# 238/238 [==============================] - 188s 789ms/step - loss: 1.1315 - acc: 0.4173 - val_loss: 1.0752 - val_acc: 0.4419
# Epoch 2/6
# 238/238 [==============================] - 187s 787ms/step - loss: 1.0876 - acc: 0.4190 - val_loss: 1.0777 - val_acc: 0.4419
# Epoch 3/6
# 238/238 [==============================] - 187s 787ms/step - loss: 1.0878 - acc: 0.4159 - val_loss: 1.0748 - val_acc: 0.4419
# Epoch 4/6
# 238/238 [==============================] - 187s 784ms/step - loss: 1.0852 - acc: 0.4189 - val_loss: 1.0758 - val_acc: 0.4419
# Epoch 5/6
# 238/238 [==============================] - 188s 789ms/step - loss: 1.0908 - acc: 0.4184 - val_loss: 1.0761 - val_acc: 0.4419
# Epoch 6/6
# 238/238 [==============================] - 188s 789ms/step - loss: 1.0844 - acc: 0.4189 - val_loss: 1.0745 - val_acc: 0.4419
# Results for current fold:
# Evaluating on train data
# 60/60 [==============================] - 33s 545ms/step - loss: 1.0827 - acc: 0.4190
# Evaluating on test data
# 7/7 [==============================] - 3s 454ms/step - loss: 1.0745 - acc: 0.4419
# Fold:  7
# Epoch 1/6
# 238/238 [==============================] - 187s 786ms/step - loss: 1.0916 - acc: 0.4199 - val_loss: 1.0840 - val_acc: 0.4147
# Epoch 2/6
# 238/238 [==============================] - 190s 798ms/step - loss: 1.0854 - acc: 0.4213 - val_loss: 1.0840 - val_acc: 0.4147
# Epoch 3/6
# 238/238 [==============================] - 189s 793ms/step - loss: 1.0866 - acc: 0.4206 - val_loss: 1.0843 - val_acc: 0.4147
# Epoch 4/6
# 238/238 [==============================] - 188s 789ms/step - loss: 1.0896 - acc: 0.4218 - val_loss: 1.0843 - val_acc: 0.4147
# Epoch 5/6
# 238/238 [==============================] - 188s 789ms/step - loss: 1.0894 - acc: 0.4172 - val_loss: 1.0888 - val_acc: 0.4147
# Epoch 6/6
# 238/238 [==============================] - 189s 794ms/step - loss: 1.0894 - acc: 0.4174 - val_loss: 1.0884 - val_acc: 0.4147
# Results for current fold:
# Evaluating on train data
# 60/60 [==============================] - 33s 555ms/step - loss: 1.0843 - acc: 0.4220
# Evaluating on test data
# 7/7 [==============================] - 3s 467ms/step - loss: 1.0884 - acc: 0.4147
# Fold:  8
# Epoch 1/6
# 238/238 [==============================] - 186s 782ms/step - loss: 1.0967 - acc: 0.4181 - val_loss: 1.0785 - val_acc: 0.4396
# Epoch 2/6
# 238/238 [==============================] - 188s 791ms/step - loss: 1.0869 - acc: 0.4194 - val_loss: 1.0773 - val_acc: 0.4396
# Epoch 3/6
# 238/238 [==============================] - 187s 785ms/step - loss: 1.0854 - acc: 0.4193 - val_loss: 1.0752 - val_acc: 0.4396
# Epoch 4/6
# 238/238 [==============================] - 188s 790ms/step - loss: 1.1049 - acc: 0.4172 - val_loss: 1.0764 - val_acc: 0.4396
# Epoch 5/6
# 238/238 [==============================] - 187s 787ms/step - loss: 1.0849 - acc: 0.4190 - val_loss: 1.0770 - val_acc: 0.4396
# Epoch 6/6
# 238/238 [==============================] - 189s 795ms/step - loss: 1.0851 - acc: 0.4184 - val_loss: 1.0799 - val_acc: 0.4396
# Results for current fold:
# Evaluating on train data
# 60/60 [==============================] - 33s 545ms/step - loss: 1.0848 - acc: 0.4193
# Evaluating on test data
# 7/7 [==============================] - 3s 433ms/step - loss: 1.0799 - acc: 0.4396
# Fold:  9
# Epoch 1/6
# 238/238 [==============================] - 188s 789ms/step - loss: 1.1071 - acc: 0.4220 - val_loss: 1.0900 - val_acc: 0.3981
# Epoch 2/6
# 238/238 [==============================] - 188s 790ms/step - loss: 1.0925 - acc: 0.4238 - val_loss: 1.0902 - val_acc: 0.3981
# Epoch 3/6
# 238/238 [==============================] - 187s 787ms/step - loss: 1.0861 - acc: 0.4235 - val_loss: 1.0898 - val_acc: 0.3981
# Epoch 4/6
# 238/238 [==============================] - 187s 785ms/step - loss: 1.0843 - acc: 0.4236 - val_loss: 1.0901 - val_acc: 0.3981
# Epoch 5/6
# 238/238 [==============================] - 188s 788ms/step - loss: 1.0916 - acc: 0.4226 - val_loss: 1.0917 - val_acc: 0.3981
# Epoch 6/6
# 238/238 [==============================] - 188s 788ms/step - loss: 1.0991 - acc: 0.4095 - val_loss: 1.0909 - val_acc: 0.3981
# Results for current fold:
# Evaluating on train data
# 60/60 [==============================] - 32s 539ms/step - loss: 1.0864 - acc: 0.4239
# Evaluating on test data
# 7/7 [==============================] - 3s 441ms/step - loss: 1.0909 - acc: 0.3981
# Fold:  10
# Epoch 1/6
# 238/238 [==============================] - 188s 790ms/step - loss: 1.0941 - acc: 0.4232 - val_loss: 1.0887 - val_acc: 0.3981
# Epoch 2/6
# 238/238 [==============================] - 188s 790ms/step - loss: 1.0861 - acc: 0.4224 - val_loss: 1.1233 - val_acc: 0.3981
# Epoch 3/6
# 238/238 [==============================] - 188s 791ms/step - loss: 1.0887 - acc: 0.4239 - val_loss: 1.0947 - val_acc: 0.3981
# Epoch 4/6
# 238/238 [==============================] - 187s 786ms/step - loss: 1.0859 - acc: 0.4228 - val_loss: 1.0895 - val_acc: 0.3981
# Epoch 5/6
# 238/238 [==============================] - 187s 784ms/step - loss: 1.0834 - acc: 0.4238 - val_loss: 1.0904 - val_acc: 0.3981
# Epoch 6/6
# 238/238 [==============================] - 187s 786ms/step - loss: 1.0880 - acc: 0.4194 - val_loss: 1.1444 - val_acc: 0.3981
# Results for current fold:
# Evaluating on train data
# 60/60 [==============================] - 32s 539ms/step - loss: 1.1192 - acc: 0.4239
# Evaluating on test data
# 7/7 [==============================] - 3s 447ms/step - loss: 1.1444 - acc: 0.3981

# %%
import statistics 

score = []
for i in results:
    score.append(i[1])
x = statistics.mean(score)
    
print("Kfold Mean: ", x)
# Out:
# Kfold Mean:  0.42654029130935667

# %% [markdown]
# ### Confusion matrix

# %%
results2 = confusion_matrix(Y_test,prediction_val)
print ('Confusion Matrix :')
print(results2) 
print ('Accuracy Score :',accuracy_score(Y_test,prediction_val))
print ('Report : ')
print (classification_report(Y_test,prediction_val))
# Out:
# Confusion Matrix :
# [[336   0   0]
#  [241   0   0]
#  [267   0   0]]
# Accuracy Score : 0.3981042654028436
# Report :
#               precision    recall  f1-score   support
#
#            0       0.40      1.00      0.57       336
#            1       0.00      0.00      0.00       241
#            2       0.00      0.00      0.00       267
#
#     accuracy                           0.40       844
#    macro avg       0.13      0.33      0.19       844
# weighted avg       0.16      0.40      0.23       844
# /opt/conda/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
