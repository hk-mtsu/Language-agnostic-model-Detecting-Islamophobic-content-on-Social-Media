# %% [markdown]
# # LSTM

# %%
# utility
import numpy as np 
import pandas as pd 
import string
import re

# visualization
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix

# model 
from tensorflow.python.keras.preprocessing.text import Tokenizer
from tensorflow.python.keras.preprocessing.sequence import pad_sequences
from keras.models import Sequential
from keras.layers import Dense, Embedding, LSTM, Bidirectional
import keras
from keras.utils.np_utils import to_categorical

#nltk and sklearn
from sklearn.preprocessing import LabelEncoder
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords

# File path
import os
import os.path
from os import path

# Translator
# import googletrans
# from googletrans import Translator

# calc accuracy
from sklearn.metrics import accuracy_score 
from sklearn.metrics import classification_report

# %% [markdown]
# ### Data

# %%
# original english file
filename  = 'Eng-Hin-data/hindi-anot-shuffled-translated'
orig_df = pd.read_csv(filename + '.csv',  
               delimiter=',')
orig_df.columns = ['Text', 'Label']

# %%
orig_df["Text"] = orig_df["Text"].astype(str)
orig_df["Label"] = orig_df["Label"].astype(str)
data = orig_df

# %%
# Displaying eg tweet
orig_df.Text[6]
# Out:
# "'Today also my cricket love has ended"

# %%
sentiment =  data['Label'].values

# %%
data.groupby('Label').describe()
# Out:
#        Text
#       count unique                                                top freq
# Label
# 0      3245   3223  Seeing this, Dhoni and Raina retired from cric...    3
# 1      2172   2142  Happy Islamic New Year "1442 Hijri" to 'Alam-e...    5
# 2      3373   3360  'Bangalore riots: Jihadi blueprint from Delhi ...    3

# %%
sns.countplot(data.Label)
plt.xlabel('Tweets')
plt.title('Number of Tweets')
# Out:
# Text(0.5, 1.0, 'Number of Tweets')

# %% [markdown]
# ### Data Preprocessing

# %%
def clean_text(text):
    text = text.lower()
    
    pattern = re.compile('http[s]?://(?:[a-zA-Z]|[0-9]|[$-_@.&+]|[!*\(\),]|(?:%[0-9a-fA-F][0-9a-fA-F]))+')
    text = pattern.sub('', text)
    text = " ".join(filter(lambda x:x[0]!='@', text.split()))
    text = text.lower()
    text = re.sub(r"i'm", "i am", text)
    text = re.sub(r"he's", "he is", text)
    text = re.sub(r"she's", "she is", text)
    text = re.sub(r"that's", "that is", text)        
    text = re.sub(r"what's", "what is", text)
    text = re.sub(r"where's", "where is", text) 
    text = re.sub(r"\'ll", " will", text)  
    text = re.sub(r"\'ve", " have", text)  
    text = re.sub(r"\'re", " are", text)
    text = re.sub(r"\'d", " would", text)
    text = re.sub(r"\'ve", " have", text)
    text = re.sub(r"won't", "will not", text)
    text = re.sub(r"don't", "do not", text)
    text = re.sub(r"did't", "did not", text)
    text = re.sub(r"can't", "can not", text)
    text = re.sub(r"it's", "it is", text)
    text = re.sub(r"couldn't", "could not", text)
    text = re.sub(r"have't", "have not", text)
    text = re.sub(r"[,.\"\'!@#$%^&*(){}?/;`~:<>+=-]", "", text)
    return text

# %%
def CleanTokenize(df):
    tweets = list()
    lines = data["Text"].values.tolist()
    
    for line in lines:
        if isinstance(line, str):
            line = clean_text(line)
        else:
            continue
        # tokenize the text
        tokens = word_tokenize(line)
        # remove puntuations
        table = str.maketrans('', '', string.punctuation)
        stripped = [w.translate(table) for w in tokens]
        # remove non alphabetic characters
        words = [word for word in stripped if word.isalpha()]
        stop_words = set(stopwords.words("english"))
        # remove stop words
        words = [w for w in words if not w in stop_words]
        tweets.append(words)
    return tweets

def Tokenize(df):
    tweets = list()
    lines = data["Text"].values.tolist()
    
    for line in lines:
        if isinstance(line, str):
            # tokenize the text
            tokens = word_tokenize(line)
        else:
            continue

        tweets.append(tokens)
    return tweets

tweets = CleanTokenize(data)
#tweets = Tokenize(data)

# %%
from collections import Counter
from wordcloud import WordCloud, ImageColorGenerator
pos_data = data.loc[data['Label'] == 1]
pos_head_lines = CleanTokenize(pos_data)
pos_lines = [j for sub in pos_head_lines for j in sub] 
word_could_dict=Counter(pos_lines)

wordcloud = WordCloud(width = 1000, height = 500).generate_from_frequencies(word_could_dict)
plt.figure(figsize=(15,8))
plt.imshow(wordcloud)
plt.axis("off")
# Out:
# (-0.5, 999.5, 499.5, -0.5)

# %% [markdown]
# ### Splitting data

# %%
validation_split = 0.1
max_length = 128


tokenizer_obj = Tokenizer()
tokenizer_obj.fit_on_texts(tweets)
sequences = tokenizer_obj.texts_to_sequences(tweets)

word_index = tokenizer_obj.word_index
print("unique tokens - ",len(word_index))
vocab_size = len(tokenizer_obj.word_index) + 1
print('vocab size -', vocab_size)

lines_pad = pad_sequences(sequences, maxlen=max_length, padding='post')
sentiment =  data['Label'].values

indices = np.arange(lines_pad.shape[0])
np.random.shuffle(indices)
lines_pad = lines_pad[indices]
sentiment = sentiment[indices]

le = LabelEncoder()
sentiment = le.fit_transform(sentiment)
# transfor from a array to a vector
sentiment = sentiment.reshape(-1,1)


num_validation_samples = int(validation_split * lines_pad.shape[0])

X_train_pad = lines_pad[:-num_validation_samples]
y_train = sentiment[:-num_validation_samples]

X_test_pad = lines_pad[-num_validation_samples:]
y_test = sentiment[-num_validation_samples:]

y_train = to_categorical(y_train)
y_test = to_categorical(y_test)
# Out:
# unique tokens -  12980
# vocab size - 12981

# %%
print('Shape of X_train_pad:', X_train_pad.shape)
print('Shape of y_train:', y_train.shape)

print('Shape of X_test_pad:', X_test_pad.shape)
print('Shape of y_test:', y_test.shape)
# Out:
# Shape of X_train_pad: (7911, 128)
# Shape of y_train: (7911, 3)
# Shape of X_test_pad: (879, 128)
# Shape of y_test: (879, 3)

# %% [markdown]
# ### Glove from paper DSWI

# %%
embeddings_index = {}

# Glove from paper DSWI
f = open('Online_supplement_1 word vectors.csv', encoding='latin1')
count = 0
for line in f:
    if count == 0:
        count = 1
        line = 0
    else:
        values = line.split()
        word = values[0]
        coefs = np.asarray(values[1:], dtype='float32')
        embeddings_index[word] = coefs
f.close()

print('Found %s word vectors.' % len(embeddings_index))
# Out:
# Found 1181930 word vectors.

# %%
embedding_dim = 50

embedding_matrix = np.zeros((len(word_index) + 1, embedding_dim))
c = 0
for word, i in word_index.items():
    embedding_vector = embeddings_index.get(word)
    if embedding_vector is not None:
        c+=1
        embedding_matrix[i] = embedding_vector

# %%
embedding_layer = Embedding(len(word_index) + 1,
                            embedding_dim,
                            weights=[embedding_matrix],
                            input_length=max_length,
                            trainable=False)

# %% [markdown]
# ## LSTM Model

# %%
def createModel(embedding_layer):
    model = Sequential()
    model.add(embedding_layer)
    model.add(LSTM(512, dropout=0.2, recurrent_dropout=0.50))
    model.add(Dense(3, activation='softmax'))

    model.compile(loss='categorical_crossentropy', optimizer = keras.optimizers.RMSprop(learning_rate=1e-3), metrics=['acc'])
    return model

model = createModel(embedding_layer)
model.summary()
# Out:
# Model: "sequential_26"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_5 (Embedding)      (None, 128, 50)           649050
# _________________________________________________________________
# lstm_26 (LSTM)               (None, 512)               1153024
# _________________________________________________________________
# dense_26 (Dense)             (None, 3)                 1539
# =================================================================
# Total params: 1,803,613
# Trainable params: 1,154,563
# Non-trainable params: 649,050
# _________________________________________________________________

# %%
history = model.fit(X_train_pad, y_train, batch_size=32, epochs=3, validation_data=(X_test_pad, y_test), verbose=2)
# Out:
# Epoch 1/3
# 248/248 - 198s - loss: 1.0948 - acc: 0.3773 - val_loss: 1.1011 - val_acc: 0.3618
# Epoch 2/3
# 248/248 - 196s - loss: 1.0856 - acc: 0.3761 - val_loss: 1.0794 - val_acc: 0.3936
# Epoch 3/3
# 248/248 - 195s - loss: 1.0885 - acc: 0.3769 - val_loss: 1.0800 - val_acc: 0.3936

# %%
results = model.evaluate(X_test_pad, y_test, batch_size=32)
# Out:
# 28/28 [==============================] - 5s 185ms/step - loss: 1.0800 - acc: 0.3936

# %%
# Plot results
acc = history.history['acc']
val_acc = history.history['val_acc']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(1, len(acc)+1)

plt.plot(epochs, acc, 'g', label='Training accuracy')
plt.plot(epochs, val_acc, 'r', label='Validation accuracy')
plt.title('Training and validation accuracy')
plt.legend()

plt.figure()

plt.plot(epochs, loss, 'g', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()

plt.show()

# %% [markdown]
# ### 10 Fold cross validation

# %%
import random
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score 
from sklearn.model_selection import KFold
# KFold cross-validation
kFold = 10
scores = []
validation_split = 0.1
max_length = 25
results = []
train_res = []
print("LSTM with Glove from DSWI: ")
for i in range(kFold):
    print("Fold: ", i+1)
    prediction_val = []
    Y_test = []
    scores=[]
    random_shuff = random.randint(1, 7000)
    X_train_pad, X_test_pad, y_train, y_test = train_test_split(lines_pad, to_categorical(sentiment), test_size=0.10, shuffle = True, random_state=random_shuff)
    model = createModel(embedding_layer)
    history = model.fit(X_train_pad, y_train, batch_size=32, epochs=6, validation_data=(X_test_pad, y_test), verbose=1)
    
    print("Results for current fold:")
    print("Evaluating on train data")
    train_res.append(model.evaluate(X_train_pad, y_train, batch_size=128))
    print("Evaluating on test data")
    results.append(model.evaluate(X_test_pad, y_test, batch_size=128))
    
    y_pred = model.predict(X_test_pad)
    for p in y_pred:
        prediction_val.append(np.argmax(p))
    for t in y_test:
        Y_test.append(np.argmax(t))
    scoreValue = accuracy_score(Y_test,prediction_val)
    scores.append(scoreValue)
# Out:
# LSTM with Glove from DSWI:
# Fold:  1
# Epoch 1/6
# 248/248 [==============================] - 197s 794ms/step - loss: 1.0962 - acc: 0.3764 - val_loss: 1.0868 - val_acc: 0.3629
# Epoch 2/6
# 248/248 [==============================] - 200s 805ms/step - loss: 1.0844 - acc: 0.3773 - val_loss: 1.0867 - val_acc: 0.3629
# Epoch 3/6
# 248/248 [==============================] - 201s 810ms/step - loss: 1.0865 - acc: 0.3811 - val_loss: 1.0882 - val_acc: 0.3629
# Epoch 4/6
# 248/248 [==============================] - 200s 806ms/step - loss: 1.0825 - acc: 0.3829 - val_loss: 1.0880 - val_acc: 0.3629
# Epoch 5/6
# 248/248 [==============================] - 199s 802ms/step - loss: 1.0823 - acc: 0.3797 - val_loss: 1.0869 - val_acc: 0.3629
# Epoch 6/6
# 248/248 [==============================] - 199s 804ms/step - loss: 1.0846 - acc: 0.3791 - val_loss: 1.1099 - val_acc: 0.3629
# Results for current fold:
# Evaluating on train data
# 62/62 [==============================] - 37s 603ms/step - loss: 1.0952 - acc: 0.3860
# Evaluating on test data
# 7/7 [==============================] - 4s 511ms/step - loss: 1.1099 - acc: 0.3629
# Fold:  2
# Epoch 1/6
# 248/248 [==============================] - 197s 796ms/step - loss: 1.0876 - acc: 0.3836 - val_loss: 1.0782 - val_acc: 0.3879
# Epoch 2/6
# 248/248 [==============================] - 199s 803ms/step - loss: 1.0847 - acc: 0.3777 - val_loss: 1.0741 - val_acc: 0.3834
# Epoch 3/6
# 248/248 [==============================] - 200s 805ms/step - loss: 1.1025 - acc: 0.3834 - val_loss: 1.0739 - val_acc: 0.3834
# Epoch 4/6
# 248/248 [==============================] - 202s 815ms/step - loss: 1.1023 - acc: 0.3761 - val_loss: 1.0843 - val_acc: 0.3834
# Epoch 5/6
# 248/248 [==============================] - 201s 809ms/step - loss: 1.0898 - acc: 0.3682 - val_loss: 1.0831 - val_acc: 0.3834
# Epoch 6/6
# 248/248 [==============================] - 204s 821ms/step - loss: 1.0840 - acc: 0.3823 - val_loss: 1.0772 - val_acc: 0.3834
# Results for current fold:
# Evaluating on train data
# 62/62 [==============================] - 36s 587ms/step - loss: 1.0827 - acc: 0.3838
# Evaluating on test data
# 7/7 [==============================] - 3s 487ms/step - loss: 1.0772 - acc: 0.3834
# Fold:  3
# Epoch 1/6
# 248/248 [==============================] - 201s 812ms/step - loss: 1.1073 - acc: 0.3783 - val_loss: 1.0825 - val_acc: 0.3788
# Epoch 2/6
# 248/248 [==============================] - 201s 811ms/step - loss: 1.0928 - acc: 0.3783 - val_loss: 1.0808 - val_acc: 0.3868
# Epoch 3/6
# 248/248 [==============================] - 199s 804ms/step - loss: 1.0835 - acc: 0.3806 - val_loss: 1.0783 - val_acc: 0.3868
# Epoch 4/6
# 248/248 [==============================] - 199s 802ms/step - loss: 1.0838 - acc: 0.3855 - val_loss: 1.0787 - val_acc: 0.3868
# Epoch 5/6
# 248/248 [==============================] - 198s 800ms/step - loss: 1.0848 - acc: 0.3777 - val_loss: 1.0757 - val_acc: 0.3868
# Epoch 6/6
# 248/248 [==============================] - 198s 799ms/step - loss: 1.0883 - acc: 0.3773 - val_loss: 1.0839 - val_acc: 0.3868
# Results for current fold:
# Evaluating on train data
# 62/62 [==============================] - 34s 552ms/step - loss: 1.0879 - acc: 0.3672
# Evaluating on test data
# 7/7 [==============================] - 3s 478ms/step - loss: 1.0839 - acc: 0.3868
# Fold:  4
# Epoch 1/6
# 248/248 [==============================] - 195s 785ms/step - loss: 1.0979 - acc: 0.3843 - val_loss: 1.0834 - val_acc: 0.3879
# Epoch 2/6
# 248/248 [==============================] - 195s 787ms/step - loss: 1.0862 - acc: 0.3809 - val_loss: 1.0773 - val_acc: 0.3879
# Epoch 3/6
# 248/248 [==============================] - 195s 786ms/step - loss: 1.0841 - acc: 0.3771 - val_loss: 1.0739 - val_acc: 0.3879
# Epoch 4/6
# 248/248 [==============================] - 196s 790ms/step - loss: 1.0868 - acc: 0.3805 - val_loss: 1.0736 - val_acc: 0.3879
# Epoch 5/6
# 248/248 [==============================] - 196s 789ms/step - loss: 1.0841 - acc: 0.3791 - val_loss: 1.0789 - val_acc: 0.3834
# Epoch 6/6
# 248/248 [==============================] - 197s 794ms/step - loss: 1.0931 - acc: 0.3694 - val_loss: 1.0766 - val_acc: 0.3834
# Results for current fold:
# Evaluating on train data
# 62/62 [==============================] - 36s 574ms/step - loss: 1.0859 - acc: 0.3676
# Evaluating on test data
# 7/7 [==============================] - 3s 489ms/step - loss: 1.0766 - acc: 0.3834
# Fold:  5
# Epoch 1/6
# 248/248 [==============================] - 199s 803ms/step - loss: 1.0936 - acc: 0.3811 - val_loss: 1.0833 - val_acc: 0.3868
# Epoch 2/6
# 248/248 [==============================] - 198s 798ms/step - loss: 1.0918 - acc: 0.3776 - val_loss: 1.0780 - val_acc: 0.3732
# Epoch 3/6
# 248/248 [==============================] - 199s 801ms/step - loss: 1.0864 - acc: 0.3680 - val_loss: 1.0802 - val_acc: 0.3868
# Epoch 4/6
# 248/248 [==============================] - 198s 799ms/step - loss: 1.0838 - acc: 0.3780 - val_loss: 1.0778 - val_acc: 0.3868
# Epoch 5/6
# 248/248 [==============================] - 199s 804ms/step - loss: 1.0837 - acc: 0.3763 - val_loss: 1.0791 - val_acc: 0.3868
# Epoch 6/6
# 248/248 [==============================] - 199s 802ms/step - loss: 1.0877 - acc: 0.3783 - val_loss: 1.0790 - val_acc: 0.3732
# Results for current fold:
# Evaluating on train data
# 62/62 [==============================] - 36s 575ms/step - loss: 1.0818 - acc: 0.3687
# Evaluating on test data
# 7/7 [==============================] - 3s 491ms/step - loss: 1.0790 - acc: 0.3732
# Fold:  6
# Epoch 1/6
# 248/248 [==============================] - 197s 796ms/step - loss: 1.0891 - acc: 0.3787 - val_loss: 1.0812 - val_acc: 0.3720
# Epoch 2/6
# 248/248 [==============================] - 197s 794ms/step - loss: 1.0842 - acc: 0.3707 - val_loss: 1.0850 - val_acc: 0.3720
# Epoch 3/6
# 248/248 [==============================] - 198s 798ms/step - loss: 1.0835 - acc: 0.3785 - val_loss: 1.0813 - val_acc: 0.3811
# Epoch 4/6
# 248/248 [==============================] - 198s 798ms/step - loss: 1.0854 - acc: 0.3821 - val_loss: 1.0818 - val_acc: 0.3720
# Epoch 5/6
# 248/248 [==============================] - 197s 795ms/step - loss: 1.0907 - acc: 0.3678 - val_loss: 1.0908 - val_acc: 0.3720
# Epoch 6/6
# 248/248 [==============================] - 198s 798ms/step - loss: 1.0862 - acc: 0.3749 - val_loss: 1.0826 - val_acc: 0.3811
# Results for current fold:
# Evaluating on train data
# 62/62 [==============================] - 35s 567ms/step - loss: 1.0822 - acc: 0.3840
# Evaluating on test data
# 7/7 [==============================] - 3s 493ms/step - loss: 1.0826 - acc: 0.3811
# Fold:  7
# Epoch 1/6
# 248/248 [==============================] - 201s 809ms/step - loss: 1.1147 - acc: 0.3702 - val_loss: 1.0885 - val_acc: 0.3845
# Epoch 2/6
# 248/248 [==============================] - 200s 808ms/step - loss: 1.0964 - acc: 0.3786 - val_loss: 1.0837 - val_acc: 0.3845
# Epoch 3/6
# 248/248 [==============================] - 199s 802ms/step - loss: 1.0819 - acc: 0.3734 - val_loss: 1.0838 - val_acc: 0.3845
# Epoch 4/6
# 248/248 [==============================] - 200s 806ms/step - loss: 1.0898 - acc: 0.3792 - val_loss: 1.0827 - val_acc: 0.3845
# Epoch 5/6
# 248/248 [==============================] - 200s 806ms/step - loss: 1.0836 - acc: 0.3719 - val_loss: 1.0963 - val_acc: 0.3845
# Epoch 6/6
# 248/248 [==============================] - 199s 802ms/step - loss: 1.0864 - acc: 0.3738 - val_loss: 1.0840 - val_acc: 0.3845
# Results for current fold:
# Evaluating on train data
# 62/62 [==============================] - 35s 562ms/step - loss: 1.0826 - acc: 0.3836
# Evaluating on test data
# 7/7 [==============================] - 3s 494ms/step - loss: 1.0840 - acc: 0.3845
# Fold:  8
# Epoch 1/6
# 248/248 [==============================] - 199s 803ms/step - loss: 1.1137 - acc: 0.3821 - val_loss: 1.0795 - val_acc: 0.3993
# Epoch 2/6
# 248/248 [==============================] - 197s 795ms/step - loss: 1.0850 - acc: 0.3699 - val_loss: 1.0757 - val_acc: 0.3777
# Epoch 3/6
# 248/248 [==============================] - 198s 797ms/step - loss: 1.1022 - acc: 0.3811 - val_loss: 1.0692 - val_acc: 0.3993
# Epoch 4/6
# 248/248 [==============================] - 199s 801ms/step - loss: 1.0863 - acc: 0.3778 - val_loss: 1.0748 - val_acc: 0.3777
# Epoch 5/6
# 248/248 [==============================] - 199s 801ms/step - loss: 1.0843 - acc: 0.3767 - val_loss: 1.0720 - val_acc: 0.3777
# Epoch 6/6
# 248/248 [==============================] - 198s 796ms/step - loss: 1.0853 - acc: 0.3787 - val_loss: 1.0721 - val_acc: 0.3777
# Results for current fold:
# Evaluating on train data
# 62/62 [==============================] - 36s 580ms/step - loss: 1.0824 - acc: 0.3844
# Evaluating on test data
# 7/7 [==============================] - 3s 486ms/step - loss: 1.0721 - acc: 0.3777
# Fold:  9
# Epoch 1/6
# 248/248 [==============================] - 198s 800ms/step - loss: 1.0929 - acc: 0.3777 - val_loss: 1.0809 - val_acc: 0.3777
# Epoch 2/6
# 248/248 [==============================] - 196s 792ms/step - loss: 1.1089 - acc: 0.3795 - val_loss: 1.0809 - val_acc: 0.3777
# Epoch 3/6
# 248/248 [==============================] - 196s 791ms/step - loss: 1.0847 - acc: 0.3790 - val_loss: 1.0799 - val_acc: 0.3777
# Epoch 4/6
# 248/248 [==============================] - 198s 799ms/step - loss: 1.0834 - acc: 0.3845 - val_loss: 1.0819 - val_acc: 0.3777
# Epoch 5/6
# 248/248 [==============================] - 199s 801ms/step - loss: 1.0832 - acc: 0.3790 - val_loss: 1.0805 - val_acc: 0.3777
# Epoch 6/6
# 248/248 [==============================] - 200s 806ms/step - loss: 1.0840 - acc: 0.3796 - val_loss: 1.0822 - val_acc: 0.3777
# Results for current fold:
# Evaluating on train data
# 62/62 [==============================] - 36s 576ms/step - loss: 1.0821 - acc: 0.3844
# Evaluating on test data
# 7/7 [==============================] - 4s 504ms/step - loss: 1.0822 - acc: 0.3777
# Fold:  10
# Epoch 1/6
# 248/248 [==============================] - 201s 809ms/step - loss: 1.1016 - acc: 0.3730 - val_loss: 1.0874 - val_acc: 0.3663
# Epoch 2/6
# 248/248 [==============================] - 202s 814ms/step - loss: 1.0848 - acc: 0.3801 - val_loss: 1.0872 - val_acc: 0.3709
# Epoch 3/6
# 248/248 [==============================] - 201s 810ms/step - loss: 1.0831 - acc: 0.3795 - val_loss: 1.0905 - val_acc: 0.3709
# Epoch 4/6
# 248/248 [==============================] - 202s 813ms/step - loss: 1.0885 - acc: 0.3841 - val_loss: 1.0892 - val_acc: 0.3709
# Epoch 5/6
# 248/248 [==============================] - 200s 807ms/step - loss: 1.0864 - acc: 0.3783 - val_loss: 1.0899 - val_acc: 0.3663
# Epoch 6/6
# 248/248 [==============================] - 201s 810ms/step - loss: 1.0929 - acc: 0.3782 - val_loss: 1.1005 - val_acc: 0.3709
# Results for current fold:
# Evaluating on train data
# 62/62 [==============================] - 36s 587ms/step - loss: 1.0877 - acc: 0.3852
# Evaluating on test data
# 7/7 [==============================] - 3s 491ms/step - loss: 1.1005 - acc: 0.3709

# %%
import statistics 

score = []
for i in results:
    score.append(i[1])
x = statistics.mean(score)
    
print("Kfold Mean: ", x)

# %% [markdown]
# ### Confusion matrix

# %%
results2 = confusion_matrix(Y_test,prediction_val)
print ('Confusion Matrix :')
print(results2) 
print ('Accuracy Score :',accuracy_score(Y_test,prediction_val))
print ('Report : ')
print (classification_report(Y_test,prediction_val))
